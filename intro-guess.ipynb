# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Domain": ["Archaea", "Bacteria", "Eukarya", "", "", "", ""],
    "Superkingdom": ["Prokaryota", "Eukaryota", "", "", "", "", ""],
    "Kingdom": ["Bacteria", "Archaea", "Protozoa", "Chromista", "Plantae", "Fungi", "Animalia"],
    "Phylum": ["Annelida", "Agmata", "Archaeocyatha", "Arthropoda", "and more...", "", ""]
})
df
# Out:
#      Domain Superkingdom    Kingdom         Phylum
# 0   Archaea   Prokaryota   Bacteria       Annelida
# 1  Bacteria    Eukaryota    Archaea         Agmata
# 2   Eukarya                Protozoa  Archaeocyatha
# 3                         Chromista     Arthropoda
# 4                           Plantae    and more...
# 5                             Fungi
# 6                          Animalia

# %%
examples = pd.read_csv('Untitled spreadsheet - Sheet2.csv')
examples
# Out:
#                         Rank        Fruit fly             Human  \
# 0                     Domain          Eukarya           Eukarya
# 1                    Kingdom         Animalia          Animalia
# 2         Phylum or division       Arthropoda          Chordata
# 3   Subphylum or subdivision         Hexapoda        Vertebrata
# 4                      Class          Insecta          Mammalia
# 5                   Subclass        Pterygota            Theria
# 6                 Superorder        Panorpida  Euarchontoglires
# 7                      Order          Diptera          Primates
# 8                   Suborder       Brachycera       Haplorrhini
# 9                     Family    Drosophilidae         Hominidae
# 10                 Subfamily    Drosophilinae         Homininae
# 11                     Tribe                -          Hominini
# 12                     Genus       Drosophila              Homo
# 13                   Species  D. melanogaster        H. sapiens
#
#                                   Pea        Fly agaric              E. coli
# 0                             Eukarya           Eukarya             Bacteria
# 1                             Plantae             Fungi                    -
# 2        Magnoliophyta (Tracheophyta)     Basidiomycota       Pseudomonadota
# 3   Magnoliophytina (Euphyllophytina)   Agaricomycotina                    -
# 4       Magnoliopsida (Equisetopsida)    Agaricomycetes  Gammaproteobacteria
# 5               Rosidae (Magnoliidae)  Agaricomycetidae                    -
# 6                             Rosanae                 -                    -
# 7                             Fabales        Agaricales     Enterobacterales
# 8                            Fabineae       Agaricineae                    -
# 9                            Fabaceae       Amanitaceae   Enterobacteriaceae
# 10                          Faboideae      Amanitoideae                    -
# 11                             Fabeae                 -                    -
# 12                              Pisum           Amanita          Escherichia
# 13                         P. sativum       A. muscaria              E. coli

# %%
df_examples = pd.DataFrame({
    "Rank": ["Domain", "Kingdom", "Phylum/Division", "Subphylum/Subdivision", "Class", "Subclass", "Superorder", "Order", "Suborder", "Family", "Subfamily", "Tribe", "Genus", "Species"],
    "Fruit Fly": ["Eukarya", "Animalia", "Athropoda", "Hexapoda", "Insecta", "Pterygota", "Panorpida", "Diptera", "Brachycera", "Drosophilidae", "Drosophilinae", "—", "Drosophila", "D. melanogaster"],
    "Human": ["Eukarya", "Animalia", "Chordata", "Vertebrata", "Mammalia", "Theria", "Euarchontoglires", "Primates", "Haplorrhini", "Hominidae", "Homininae", "Hominini", "Homo", "H. Sapiens"]
})
df_examples
# Out:
#                      Rank        Fruit Fly             Human
# 0                  Domain          Eukarya           Eukarya
# 1                 Kingdom         Animalia          Animalia
# 2         Phylum/Division        Athropoda          Chordata
# 3   Subphylum/Subdivision         Hexapoda        Vertebrata
# 4                   Class          Insecta          Mammalia
# 5                Subclass        Pterygota            Theria
# 6              Superorder        Panorpida  Euarchontoglires
# 7                   Order          Diptera          Primates
# 8                Suborder       Brachycera       Haplorrhini
# 9                  Family    Drosophilidae         Hominidae
# 10              Subfamily    Drosophilinae         Homininae
# 11                  Tribe                —          Hominini
# 12                  Genus       Drosophila              Homo
# 13                Species  D. melanogaster        H. Sapiens

# %%
df_examples.loc[((df_examples["Rank"] == "Domain") & (df_examples["Fruit Fly"] == "Eukarya"))]
# Out:
#      Rank Fruit Fly    Human
# 0  Domain   Eukarya  Eukarya

# %%
df_game = pd.read_csv('Untitled Documentcase.csv', header = 12)
df_game.head()
# Out:
#    game  score  disks  formula       level  disk  push  startPos      endPos  \
# 0     1     98      3      NaN  Washington     1    50        15  259.999999
# 1     1     98      3      NaN  Washington     2    57        15  294.299258
# 2     1     98      3      NaN  Washington     3    64        15  328.598678
# 3     3      0      1      NaN  Washington     1    84        15   17.828680
# 4     4      0      1      NaN  Washington     1    78        15  397.197514
#
#      pad  points
# 0  three      50
# 1    NaN       0
# 2   four      48
# 3    NaN       0
# 4    NaN       0

# %%
df_game.plot(x = "push", y = "endPos", style = ".-", color = "#3c81a8", title = "Force vs. End Position of Shuffleboard Game", grid = True, marker = "o", ms = 10, markerfacecolor = 'red')
# Out:
# c:\Users\jaspe\Documents\GitHub\Oxbridge-CamTrad-Data-Science-2022\venv\lib\site-packages\pandas\plotting\_matplotlib\core.py:755: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string ".-" (-> marker='.'). The keyword argument will take precedence.
#   return ax.plot(*args, **kwds)
# <AxesSubplot:title={'center':'Force vs. End Position of Shuffleboard Game'}, xlabel='push'>

# %%
import seaborn as sns
sns.set_theme()
sns.cubehelix_palette(as_cmap=True)
plotted = sns.relplot(x='push', y='endPos', data = df_game)
plotted.figure.savefig("out.png")
